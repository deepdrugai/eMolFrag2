# %% [markdown]
# <a href="https://colab.research.google.com/github/deepdrugai/eMolFrag2/blob/eMolFrag2-packaging/eMolFrag2_Notebook%20(colab%20packaging).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install eMolFrag
# %pip install git+https://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@github.com/deepdrugai/eMolFrag2.git@eMolFrag2-packaging

# %%
# Download Data.zip and Unzip
# !curl -GLf -H "Authorization: token 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" -H 'Accept: application/vnd.github.v3.raw' https://api.github.com/repos/deepdrugai/eMolFrag2/contents/data.zip?ref=eMolFrag2-packaging -o data.zip
# !unzip data.zip

# %%
# Run eMolFrag
# !emolfrag -i data/db-files/mol2 -o output/ -n
